# %%
from data_generator import (
    generate_collocation_points,
    generate_boundary_points,
    generate_initial_condition
)

# u0(x) = sin(pi * x)
import numpy as np
u0_fn = lambda x: np.sin(np.pi * x)

colloc = generate_collocation_points(10000)
bound = generate_boundary_points(2000)
init_X, init_u = generate_initial_condition(2000, u0_fn=u0_fn)

print(colloc.shape, bound.shape, init_X.shape, init_u.shape)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from src.data_generator import (
#       2     generate_collocation_points,
#       3     generate_boundary_points,
#       4     generate_initial_condition
#       5 )
#       7 # u0(x) = sin(pi * x)
#       8 import numpy as np
#
# ModuleNotFoundError: No module named 'src'
